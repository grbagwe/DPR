# %%
import pandas as pd

# %%
import torch 

tensor = torch.randn(8, 768)

# %%
a = [i for i in range(8)]
b = [ 3, 5]

# %%
keep_indices = [i for i in range(tensor.size(0)) if i not in b]

# %%
tensor[keep_indices].size()
# Out:
# torch.Size([6, 768])

# %%
df = pd.read_json("./downloads/data/retriever/nq-train.json")

# %%
df.head()
# Out:
#             dataset                                           question  \
# 0  nq_dev_psgs_w100                who sings does he love me with reba
# 1  nq_dev_psgs_w100            where do the great lakes meet the ocean
# 2  nq_dev_psgs_w100  when does the new my hero academia movie come out
# 3  nq_dev_psgs_w100          who was the creator of victoria 's secret
# 4  nq_dev_psgs_w100      when did wesley leave last of the summer wine
#
#                       answers  \
# 0               [Linda Davis]
# 1  [the Saint Lawrence River]
# 2             [July 5 , 2018]
# 3               [Roy Raymond]
# 4                      [2002]
#
#                                        positive_ctxs  \
# 0  [{'title': 'Does He Love You', 'text': 'Does H...
# 1  [{'title': 'Great Lakes', 'text': 'Great Lakes...
# 2  [{'title': 'My Hero Academia: Two Heroes', 'te...
# 3  [{'title': 'Victoria's Secret', 'text': 'the s...
# 4  [{'title': 'Gordon Wharmby', 'text': 'made his...
#
# ...

# %%
len(df["positive_ctxs"][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(df["positive_ctxs"][0])
#
# NameError: name 'df' is not defined

# %%
len(df["hard_negative_ctxs"][5])
# Out:
# 99

# %%
df["negative_ctxs"][0]
# Out:
# [{'title': 'Cormac McCarthy',
#   'text': 'chores of the house, Lee was asked by Cormac to also get a day job so he could focus on his novel writing. Dismayed with the situation, she moved to Wyoming, where she filed for divorce and landed her first job teaching. Cormac McCarthy is fluent in Spanish and lived in Ibiza, Spain, in the 1960s and later settled in El Paso, Texas, where he lived for nearly 20 years. In an interview with Richard B. Woodward from "The New York Times", "McCarthy doesn\'t drink anymore – he quit 16 years ago in El Paso, with one of his young',
#   'score': 0,
#   'title_score': 0,
#   'passage_id': '2145653'},
#  {'title': 'Pragmatic Sanction of 1549',
# ...
