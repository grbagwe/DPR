# %%
import torch

# %%
temp_neg_vectors = torch.empty(10, 768 )
temp_neg_vectors[0].shape, temp_neg_vectors[0]
# Out:
# (torch.Size([768]),
#  tensor([9.3340e-09, 1.0257e-08, 1.6149e-07, 1.3567e-19, 6.4094e-10, 8.1424e-13,
#          1.4585e-19, 6.3369e-10, 5.2002e+22, 2.5038e-12, 4.0046e-11, 6.4097e-10,
#          6.4090e-10, 2.3301e-09, 2.5641e-09, 1.6149e-07, 1.7035e+28, 1.3563e-19,
#          1.3563e-19, 4.0046e-11, 6.4097e-10, 6.4090e-10, 2.3301e-09, 2.5641e-09,
#          1.6149e-07, 1.3567e-19, 1.6594e-07, 1.3028e-11, 1.4586e-19, 4.0559e-08,
#          5.2300e+22, 2.5609e-12, 4.0046e-11, 6.4097e-10, 6.4090e-10, 2.0190e-19,
#          1.3563e-19, 1.3563e-19, 4.1536e-05, 5.3190e+22, 2.5464e-12, 4.0956e-11,
#          1.0258e-08, 2.6219e-09, 2.3301e-09, 2.5641e-09, 1.6149e-07, 1.3567e-19,
#          4.2720e-05, 1.3028e-11, 1.4586e-19, 4.1532e-05, 5.3775e+22, 2.5751e-12,
#          1.3589e-19, 1.3563e-19, 1.3563e-19, 1.0546e-08, 1.3029e-11, 1.4586e-19,
#          1.6223e-07, 5.2888e+22, 2.5751e-12, 4.0501e-11, 6.6389e-07, 1.6780e-07,
# ...

# %%
temp_neg_vectors.size()
# Out:
# torch.Size([2, 1, 768])

# %%
torch.mean(temp_neg_vectors, dim = 0).shape
# Out:
# torch.Size([768])

# %%
torch.cat((temp_neg_vectors[0], a), 0)
# Out:
# tensor([[ 2.8026e-45,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#           8.4078e-45,  4.5901e-41],
#         [ 1.6603e+00, -1.5932e-01, -7.6482e-01,  ..., -9.0852e-01,
#           6.6096e-01,  6.5744e-01]])

# %%
keep_neg_indx = [10+i+1 for i in range(5)]

# %%
keep_neg_indx
# Out:
# [11, 12, 13, 14, 15]
